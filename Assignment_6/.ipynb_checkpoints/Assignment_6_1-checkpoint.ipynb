# %%
using Pkg

# %%
Pkg.add("ScikitLearn")
Pkg.add("DataFrames")
Pkg.add("CSV")
Pkg.add("PyCall")
Pkg.add("PyPlot");
Pkg.add("MultivariateStats");
# Out:
#    Updating registry at `C:\Users\conno\.julia\registries\General`
#   Resolving package versions...
# No Changes to `C:\Users\conno\.julia\environments\v1.5\Project.toml`
# No Changes to `C:\Users\conno\.julia\environments\v1.5\Manifest.toml`
#   Resolving package versions...
# No Changes to `C:\Users\conno\.julia\environments\v1.5\Project.toml`
# No Changes to `C:\Users\conno\.julia\environments\v1.5\Manifest.toml`
#   Resolving package versions...
# No Changes to `C:\Users\conno\.julia\environments\v1.5\Project.toml`
# No Changes to `C:\Users\conno\.julia\environments\v1.5\Manifest.toml`
#   Resolving package versions...
# No Changes to `C:\Users\conno\.julia\environments\v1.5\Project.toml`
# No Changes to `C:\Users\conno\.julia\environments\v1.5\Manifest.toml`
#   Resolving package versions...
# No Changes to `C:\Users\conno\.julia\environments\v1.5\Project.toml`
# No Changes to `C:\Users\conno\.julia\environments\v1.5\Manifest.toml`
#   Resolving package versions...
# No Changes to `C:\Users\conno\.julia\environments\v1.5\Project.toml`
# No Changes to `C:\Users\conno\.julia\environments\v1.5\Manifest.toml`

# %%
using ScikitLearn
using DataFrames
using CSV
using PyCall
using PyPlot
using MultivariateStats

# %%
import ScikitLearn: CrossValidation

# %%
# @sk_import decomposition: PCA;
@sk_import preprocessing: MinMaxScaler;
@sk_import neighbors: KNeighborsClassifier;
@sk_import svm: LinearSVC;

# %%
np = pyimport("numpy");

# %%
df = CSV.File("01_hdp.csv"; header = true) |> DataFrame;

# %%
X_df = [df.tumorsize df.co2 df.lungcapacity df.Age df.WBC df.RBC df.BMI df.IL6 df.CRP df.Medicaid];

# %%
y_df = df.CancerStage;

# %%
X = convert(Array, X_df);
y = convert(Array, y_df);

# %% [markdown]
# ## Normalizing the data and then splitting it into testing and training

# %%
mms = MinMaxScaler();
X_norm = mms.fit_transform(X);

# %%
X_train, X_test, y_train, y_test = CrossValidation.train_test_split(X_norm, y, test_size=0.30);

# %% [markdown]
# ## Creating and fitting the PCA models with the training data. Then transforming the training and testing data with the trained model

# %%
pca_models = [];
X_train_pca = [];
X_test_pca = [];
test_times = [];
for i in 1:10
    time = @elapsed begin
    push!(pca_models, fit(PCA, X_train; maxoutdim=i, inverse=true);
    push!(X_test_pca, transform(pca_models[i]; X_test);
    end
    push!(test_times, time);
    push!(X_train_pca, transform(pca_models[i]; X_train);
end
# Out:
# syntax: unexpected "end"
#
# Stacktrace:
#  [1] top-level scope at In[19]:9
#  [2] include_string(::Function, ::Module, ::String, ::String) at .\loading.jl:1091

# %% [markdown]
# ## Determining the amount of components needed to maintain 90% explained variance

# %%
cumV = np.cumsum(pca_models[10].explained_variance_ratio_);
nComp = 0;
for i in 1:10
    if(cumV[i] > 0.9)
        nComp = i+1;
        break;
    end
end

# %%
plt.plot(np.cumsum(pca_models[10].explained_variance_ratio_),"-o")
plt.xlabel("Number of Components");
plt.ylabel("Cumulative Explained Variance");
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)

# %%
print("You need ", nComp, " principal components to preserve an explained varience of 90%");
# Out:
# You need 9 principal components to preserve an explained varience of 90%

# %% [markdown]
# ## Using KNN as my classifier with the PCA data

# %%
neighbors = 450;
knn = KNeighborsClassifier(neighbors, metric="minkowski");
training_scores_knn = [];
testing_scores_knn = [];
for i in 1:10
    knn.fit(X_train_pca[i], y_train);
    train_score = knn.score(X_train_pca[i], y_train);
    test_score =  knn.score(X_test_pca[i], y_test);
    println("Training accuracy with ", neighbors, " neighbors with ",i, " PCA component is: ", train_score);
    println("Testing accuracy with ", neighbors, " neighbors with ",i, " PCA component is: ", test_score);
    println();
    push!(training_scores_knn, train_score);
    push!(testing_scores_knn, test_score);
end
# Out:
# Training accuracy with 450 neighbors with 1 PCA component is: 0.3975196916373387
# Testing accuracy with 450 neighbors with 1 PCA component is: 0.4053948397185301
#
# Training accuracy with 450 neighbors with 2 PCA component is: 0.4000335176805765
# Testing accuracy with 450 neighbors with 2 PCA component is: 0.4077404222048475
#
# Training accuracy with 450 neighbors with 3 PCA component is: 0.4033852857382269
# Testing accuracy with 450 neighbors with 3 PCA component is: 0.4108678655199374
#
# Training accuracy with 450 neighbors with 4 PCA component is: 0.4152840623428859
# Testing accuracy with 450 neighbors with 4 PCA component is: 0.4218139171227521
#
# Training accuracy with 450 neighbors with 5 PCA component is: 0.4167923579688286
# Testing accuracy with 450 neighbors with 5 PCA component is: 0.4253322908522283
#
# Training accuracy with 450 neighbors with 6 PCA component is: 0.43774090832914364
# Testing accuracy with 450 neighbors with 6 PCA component is: 0.4437060203283815
#
# Training accuracy with 450 neighbors with 7 PCA component is: 0.4384112619406737
# Testing accuracy with 450 neighbors with 7 PCA component is: 0.4433150899139953
#
# Training accuracy with 450 neighbors with 8 PCA component is: 0.4367353779118485
# Testing accuracy with 450 neighbors with 8 PCA component is: 0.4433150899139953
#
# Training accuracy with 450 neighbors with 9 PCA component is: 0.4375733199262611
# Testing accuracy with 450 neighbors with 9 PCA component is: 0.4480062548866302
#
# Training accuracy with 450 neighbors with 10 PCA component is: 0.43874643874643876
# Testing accuracy with 450 neighbors with 10 PCA component is: 0.44175136825645034

# %%
svc = LinearSVC();
training_scores_svc = [];
testing_scores_svc = [];
for i in 1:10
    svc.fit(X_train_pca[i], y_train);
    train_score = svc.score(X_train_pca[i], y_train);
    test_score =  svc.score(X_test_pca[i], y_test);
    println("Training accuracy with ",i, " PCA component is: ", train_score);
    println("Testing accuracy with ",i, " PCA component is: ", test_score);
    println();
    push!(training_scores_svc, train_score);
    push!(testing_scores_svc, test_score);
end
# Out:
# Training accuracy with 1 PCA component is: 0.3975196916373387
# Testing accuracy with 1 PCA component is: 0.4053948397185301
#
# Training accuracy with 2 PCA component is: 0.39785486844310375
# Testing accuracy with 2 PCA component is: 0.4053948397185301
#
# Training accuracy with 3 PCA component is: 0.40372046254399196
# Testing accuracy with 3 PCA component is: 0.4151681000781861
#
# Training accuracy with 4 PCA component is: 0.4156192391486509
# Testing accuracy with 4 PCA component is: 0.43979671618451915
#
# Training accuracy with 5 PCA component is: 0.41763029998324114
# Testing accuracy with 5 PCA component is: 0.4390148553557467
#
# Training accuracy with 6 PCA component is: 0.4494720965309201
# Testing accuracy with 6 PCA component is: 0.4687255668491009
#
# Training accuracy with 7 PCA component is: 0.45031003854533264
# Testing accuracy with 7 PCA component is: 0.4628616106333073
#
# Training accuracy with 8 PCA component is: 0.4494720965309201
# Testing accuracy with 8 PCA component is: 0.46481626270523846
#
# Training accuracy with 9 PCA component is: 0.4493045081280375
# Testing accuracy with 9 PCA component is: 0.462470680218921
#
# Training accuracy with 10 PCA component is: 0.4498072733366851
# Testing accuracy with 10 PCA component is: 0.46364347146207974

# %% [markdown]
# ## Plotting the PCA components vs. accuracy for the training and testing data sets

# %%
plt.plot(1:10, training_scores_knn);
plt.xlabel("Number of Components");
plt.ylabel("Accuracy");
plt.title("Accuracy (Training Set) vs. # of Components");
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)

# %%
plt.plot(1:10, testing_scores_knn);
plt.xlabel("Number of Components");
plt.ylabel("Accuracy");
plt.title("Accuracy (Testing Set) vs. # of Components (knn)");
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)

# %%
plt.plot(1:10, training_scores_svc);
plt.xlabel("Number of Components");
plt.ylabel("Accuracy");
plt.title("Accuracy (Training Set) vs. # of Components (svc)");
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)

# %%
plt.plot(1:10, testing_scores_svc);
plt.xlabel("Number of Components");
plt.ylabel("Accuracy");
plt.title("Accuracy (Testing Set) vs. # of Components (svc)");
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)

# %%
plt.plot(1:10, test_times);
plt.xlabel("Number of Components");
plt.ylabel("Time");
plt.title("Time (Testing Set) vs. # of Components");
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
