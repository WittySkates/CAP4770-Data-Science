# %%
using Pkg

# %%
Pkg.add("ScikitLearn")
Pkg.add("DataFrames")
Pkg.add("CSV")
Pkg.add("PyCall")
Pkg.add("PyPlot");
Pkg.add("MultivariateStats");
# Out:
#    Updating registry at `C:\Users\conno\.julia\registries\General`

# %%
using ScikitLearn
using DataFrames
using CSV
using PyCall
using PyPlot
using MultivariateStats

# %%
import ScikitLearn: CrossValidation

# %%
@sk_import decomposition: PCA;
@sk_import preprocessing: MinMaxScaler;
@sk_import neighbors: KNeighborsClassifier;

# %%
np = pyimport("numpy");

# %%
df = CSV.File("01_hdp.csv"; header = true) |> DataFrame;

# %%
X_df = [df.tumorsize df.co2 df.lungcapacity df.Age df.WBC df.RBC df.BMI df.IL6 df.CRP df.Medicaid];

# %%
y_df = df.CancerStage;

# %%
X = convert(Array, X_df);
y = convert(Array, y_df);

# %% [markdown]
# ## Normalizing the data and then splitting it into testing and training

# %%
mms = MinMaxScaler();
X_norm = mms.fit_transform(X);

# %%
X_train, X_test, y_train, y_test = CrossValidation.train_test_split(X_norm, y, test_size=0.30);

# %% [markdown]
# ## Creating and fitting the PCA models with the training data. Then transforming the training and testing data with the trained model

# %%
pca_models = [];
X_train_pca = [];
X_test_pca = [];
test_times = [];
for i in 1:10
    time = @elapsed begin
    push!(pca_models, PCA(n_components=i))
    pca_models[i].fit(X_train);
    push!(X_test_pca, pca_models[i].transform(X_test));
    end
    push!(test_times, time);
    push!(X_train_pca, pca_models[i].transform(X_train));
end

# %% [markdown]
# ## Determining the amount of components needed to maintain 90% explained variance

# %%
cumV = np.cumsum(pca_models[10].explained_variance_ratio_);
nComp = 0;
for i in 1:10
    if(cumV[i] > 0.9)
        nComp = i+1;
        break;
    end
end

# %%
plt.plot(np.cumsum(pca_models[10].explained_variance_ratio_),"-o")
plt.xlabel("Number of Components");
plt.ylabel("Cumulative Explained Variance");
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)

# %%
print("You need ", nComp, " principal components to preserve an explained varience of 90%");
# Out:
# You need 9 principal components to preserve an explained varience of 90%

# %% [markdown]
# ## Using KNN as my classifier with the PCA data

# %%
neighbors = 450;
knn = KNeighborsClassifier(neighbors, metric="minkowski");
training_scores = [];
testing_scores = [];
for i in 1:10
    knn.fit(X_train_pca[i], y_train);
    train_score = knn.score(X_train_pca[i], y_train);
    test_score =  knn.score(X_test_pca[i], y_test);
    println("Training accuracy with ", neighbors, " neighbors with ",i, " PCA component is: ", train_score);
    println("Testing accuracy with ", neighbors, " neighbors with ",i, " PCA component is: ", test_score);
    println();
    push!(training_scores, train_score);
    push!(testing_scores, test_score);
end
# Out:
# Training accuracy with 450 neighbors with 1 PCA component is: 0.3991955756661639
# Testing accuracy with 450 neighbors with 1 PCA component is: 0.4014855355746677
#
# Training accuracy with 450 neighbors with 2 PCA component is: 0.40204457851516673
# Testing accuracy with 450 neighbors with 2 PCA component is: 0.4077404222048475
#
# Training accuracy with 450 neighbors with 3 PCA component is: 0.4047259929612871
# Testing accuracy with 450 neighbors with 3 PCA component is: 0.40500390930414387
#
# Training accuracy with 450 neighbors with 4 PCA component is: 0.4169599463717111
# Testing accuracy with 450 neighbors with 4 PCA component is: 0.4222048475371384
#
# Training accuracy with 450 neighbors with 5 PCA component is: 0.416289592760181
# Testing accuracy with 450 neighbors with 5 PCA component is: 0.4218139171227521
#
# Training accuracy with 450 neighbors with 6 PCA component is: 0.4405899111781465
# Testing accuracy with 450 neighbors with 6 PCA component is: 0.44448788115715404
#
# Training accuracy with 450 neighbors with 7 PCA component is: 0.43891402714932126
# Testing accuracy with 450 neighbors with 7 PCA component is: 0.44175136825645034
#
# Training accuracy with 450 neighbors with 8 PCA component is: 0.43807608513490864
# Testing accuracy with 450 neighbors with 8 PCA component is: 0.44566067240031276
#
# Training accuracy with 450 neighbors with 9 PCA component is: 0.43556225909167084
# Testing accuracy with 450 neighbors with 9 PCA component is: 0.4401876465989054
#
# Training accuracy with 450 neighbors with 10 PCA component is: 0.4343891402714932
# Testing accuracy with 450 neighbors with 10 PCA component is: 0.43862392494136043

# %% [markdown]
# ## Plotting the PCA components vs. accuracy for the training and testing data sets

# %%
plt.plot(1:10, training_scores);
plt.xlabel("Number of Components");
plt.ylabel("Accuracy");
plt.title("Accuracy (Training Set) vs. # of Components");
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)

# %%
plt.plot(1:10, testing_scores);
plt.xlabel("Number of Components");
plt.ylabel("Accuracy");
plt.title("Accuracy (Testing Set) vs. # of Components");
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)

# %%
plt.plot(1:10, test_times);
plt.xlabel("Number of Components");
plt.ylabel("Time to Train");
plt.title("Time (Testing Set) vs. # of Components");
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
